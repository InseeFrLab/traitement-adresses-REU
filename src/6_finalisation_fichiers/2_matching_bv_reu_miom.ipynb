# %% [markdown]
# # Matching des identifiants des bureaux de vote du REU et du Ministère de l'Intérieur

# %% [markdown]
# ## Imports

# %% [markdown]
# ### Packages

# %%
import os
import pandas as pd
import re
from unidecode import unidecode
# Out:
# Requirement already satisfied: unidecode in /opt/mamba/lib/python3.10/site-packages (1.3.6)

# %% [markdown]
# ### Fonctions

# %%
def complete_postal_code(x):
    # The result shall be a 5-digits postal code
    x = str(x or "").strip()
    while len(x) > 0 and x[0] in ["-", "o"]:
        x = x[1:]
    nb_digits = min(len(x), 5)
    return ((5 - nb_digits) * "0" + x)[:5]

# %%
list_chars = [".", ",", ";", ":", "#", "°", "*", '"', "-", "/", "'", "  ", "BUREAU"]  # Undesirable punctuation

def clean_place_name(x):
    """
    Removes what is between parenthesis or brackets, lowers the string and removes undesirable punctuation
    """
    x_clean = re.sub("[\(\[].*?[\)\]]", "", x)
    for character in list_chars:
        x_clean = x_clean.replace(character, " ")
    x_clean = ''.join([str(int(i)) + " " if i.isnumeric() else i.strip() for i in x_clean.split(" ") if len(i) > 0])
    while len(x_clean) > 0 and x_clean[0] == '0':
        x_clean = x_clean[1:]
    return unidecode(x_clean).strip()

# %% [markdown]
# ### Données

# %%
os.system(f"mc cp s3/projet-adresses-reu/table_bv.parquet table_bv.parquet")

# %%
df_bv_originale = pd.read_parquet('table_bv.parquet')
df_bv_originale['nb_adresses_final'] = df_bv_originale['nb_adresses_final'].fillna(0)

# %%
df_bv = df_bv_originale.copy()
df_bv.head(3)
# Out:
#   id_brut_reu id_brut_insee code_commune code     libelle_reu num_voie_reu  \
# 0     01001_1        1001_1        01001    1        bureau 1
# 1     01002_1        1002_1        01002    1          mairie            1
# 2     01004_1        1004_1        01004    1  b1 espace 1500
#
#              voie_reu cp_reu            commune_reu  nb_adresses_initial  \
# 0     Salle des fêtes  01400  abergement clemenciat                  448
# 1  Place de la Mairie  01640  l abergement de varey                  157
# 2    AVENUE LEON BLUM  01500      amberieu en bugey                  633
#
#    nb_adresses_final
# 0              448.0
# 1              143.0
# 2              630.0

# %%
df_bv["code"] = df_bv["code"].apply(clean_place_name)
df_bv["departement"] = df_bv["code_commune"].apply(lambda x: x[:2])

# %%
os.system(f"mc cp s3/projet-adresses-reu/resultats-par-niveau-burvot-t1-france-entiere.xlsx table_miom.xlsx")

# %%
df_miom_originale = pd.read_excel('table_miom.xlsx', dtype=str)

# %%
df_miom = df_miom_originale.copy()
df_miom
# Out:
#       Code du département           Libellé du département  \
# 0                      01                              Ain
# 1                      01                              Ain
# 2                      01                              Ain
# 3                      01                              Ain
# 4                      01                              Ain
# ...                   ...                              ...
# 69677                  ZZ  Français établis hors de France
# 69678                  ZZ  Français établis hors de France
# 69679                  ZZ  Français établis hors de France
# 69680                  ZZ  Français établis hors de France
# 69681                  ZZ  Français établis hors de France
#
#       Code de la circonscription Libellé de la circonscription  \
# 0                             04          4ème circonscription
# 1                             05          5ème circonscription
# 2                             05          5ème circonscription
# 3                             05          5ème circonscription
# 4                             05          5ème circonscription
# ...                          ...                           ...
# 69677                         06          6ème circonscription
# 69678                         11         11ème circonscription
# 69679                         11         11ème circonscription
# 69680                         02          2ème circonscription
# 69681                         02          2ème circonscription
#
#       Code de la commune    Libellé de la commune Code du b.vote Inscrits  \
# 0                    001  L'Abergement-Clémenciat           0001      645
# 1                    002    L'Abergement-de-Varey           0001      213
# 2                    004        Ambérieu-en-Bugey           0001     1129
# 3                    004        Ambérieu-en-Bugey           0002     1128
# 4                    004        Ambérieu-en-Bugey           0003     1213
# ...                  ...                      ...            ...      ...
# 69677                229                   Zurich           0001    24868
# 69678                231                   Taipei           0001     1709
# 69679                233             Nour-Soultan           0001      117
# 69680                234                Monterrey           0001      713
# 69681                235         Bahamas (Nassau)           0001      136
#
#       Abstentions % Abs/Ins  ... Unnamed: 95 Unnamed: 96 Unnamed: 97  \
# 0             108     16.74  ...           3        0.47        0.58
# 1              38     17.84  ...           3        1.41        1.75
# 2             266     23.56  ...           8        0.71        0.95
# 3             265     23.49  ...           4        0.35        0.48
# 4             246     20.28  ...           3        0.25        0.32
# ...           ...       ...  ...         ...         ...         ...
# 69677       14101      56.7  ...          47        0.19        0.44
# 69678         942     55.12  ...          10        0.59        1.32
# 69679          64      54.7  ...           0           0           0
# 69680         553     77.56  ...           1        0.14        0.63
# 69681          78     57.35  ...           0           0           0
#
#       Unnamed: 98 Unnamed: 99   Unnamed: 100 Unnamed: 101 Unnamed: 102  \
# 0              12           M  DUPONT-AIGNAN      Nicolas           21
# 1              12           M  DUPONT-AIGNAN      Nicolas            0
# 2              12           M  DUPONT-AIGNAN      Nicolas           13
# 3              12           M  DUPONT-AIGNAN      Nicolas           20
# 4              12           M  DUPONT-AIGNAN      Nicolas           19
# ...           ...         ...            ...          ...          ...
# 69677          12           M  DUPONT-AIGNAN      Nicolas          189
# 69678          12           M  DUPONT-AIGNAN      Nicolas           10
# 69679          12           M  DUPONT-AIGNAN      Nicolas            1
# 69680          12           M  DUPONT-AIGNAN      Nicolas            1
# 69681          12           M  DUPONT-AIGNAN      Nicolas            1
#
#       Unnamed: 103 Unnamed: 104
# 0             3.26         4.04
# 1                0            0
# 2             1.15         1.55
# 3             1.77         2.38
# 4             1.57            2
# ...            ...          ...
# 69677         0.76         1.77
# 69678         0.59         1.32
# 69679         0.85         1.96
# 69680         0.14         0.63
# 69681         0.74         1.82
#
# [69682 rows x 105 columns]

# %% [markdown]
# ### Informations du Ministère

# %%
table_correspondance_outremer = {
    "ZA":"971",
    "ZB":"972",
    "ZC":"973",
    "ZD":"974",
    "ZS":"975",
    "ZM":"976",
    "ZY":"977",
    "ZT":"978",
    "ZW":"986",
    "ZP":"987"
}

# %% [markdown]
# ## Preprocessing des bv MIOM

# %% [markdown]
# ### Pré-création id_brut

# %%
df_miom["code_commune"] = df_miom["Code du département"] + df_miom["Code de la commune"]
df_miom["code"] = df_miom["Code du b.vote"]
df_miom["commune_miom"] = df_miom["Libellé de la commune"]
df_miom["libelle_departement_miom"] = df_miom["Libellé du département"]

# %%
df_miom['id_brut_miom'] = \
    df_miom['code_commune'].fillna("") + '_' + df_miom['code'].fillna("")

# %% [markdown]
# ### Post création id_brut

# %%
df_miom["code"] = df_miom["code"].astype(str).str.lower().apply(clean_place_name)

# %%
df_miom["Code de la commune"] = df_miom.apply(
    lambda row: row["Code de la commune"][1:] if row["Code du département"] in table_correspondance_outremer.keys() else row["Code de la commune"],
    axis=1
)

df_miom["Code du département"] = df_miom["Code du département"].apply(
    lambda x: table_correspondance_outremer[x] if x in table_correspondance_outremer.keys() else x
)
df_miom["code_commune"] = df_miom["Code du département"] + df_miom["Code de la commune"]
df_miom["departement_miom"] = df_miom["Code du département"]

# %%
df_miom['id_clean_miom'] = \
    df_miom['code_commune'].fillna("") + '_' + df_miom['code'].fillna("")

# %%
df_bv_miom = df_miom[["id_brut_miom", "id_clean_miom", "code_commune", "code", "commune_miom", "departement_miom", "libelle_departement_miom"]]
df_bv_miom
# Out:
#       id_brut_miom id_clean_miom code_commune code             commune_miom  \
# 0       01001_0001       01001_1        01001    1  L'Abergement-Clémenciat
# 1       01002_0001       01002_1        01002    1    L'Abergement-de-Varey
# 2       01004_0001       01004_1        01004    1        Ambérieu-en-Bugey
# 3       01004_0002       01004_2        01004    2        Ambérieu-en-Bugey
# 4       01004_0003       01004_3        01004    3        Ambérieu-en-Bugey
# ...            ...           ...          ...  ...                      ...
# 69677   ZZ229_0001       ZZ229_1        ZZ229    1                   Zurich
# 69678   ZZ231_0001       ZZ231_1        ZZ231    1                   Taipei
# 69679   ZZ233_0001       ZZ233_1        ZZ233    1             Nour-Soultan
# 69680   ZZ234_0001       ZZ234_1        ZZ234    1                Monterrey
# 69681   ZZ235_0001       ZZ235_1        ZZ235    1         Bahamas (Nassau)
#
#       departement_miom         libelle_departement_miom
# 0                   01                              Ain
# 1                   01                              Ain
# 2                   01                              Ain
# 3                   01                              Ain
# 4                   01                              Ain
# ...                ...                              ...
# 69677               ZZ  Français établis hors de France
# 69678               ZZ  Français établis hors de France
# 69679               ZZ  Français établis hors de France
# 69680               ZZ  Français établis hors de France
# 69681               ZZ  Français établis hors de France
#
# [69682 rows x 7 columns]

# %%
df_miom[df_miom["Code du département"].apply(lambda x: not(x.isnumeric()))].groupby(['Code du département']).count()
# Out:
#                      Libellé du département  Code de la circonscription  \
# Code du département
# 2A                                      220                         220
# 2B                                      325                         325
# ZN                                      297                         297
# ZX                                       26                          26
# ZZ                                      210                         210
#
#                      Libellé de la circonscription  Code de la commune  \
# Code du département
# 2A                                             220                 220
# 2B                                             325                 325
# ZN                                             297                 297
# ZX                                              26                  26
# ZZ                                             210                 210
#
#                      Libellé de la commune  Code du b.vote  Inscrits  \
# Code du département
# 2A                                     220             220       220
# 2B                                     325             325       325
# ZN                                     297             297       297
# ZX                                      26              26        26
# ZZ                                     210             210       210
#
#                      Abstentions  % Abs/Ins  Votants  ...  Unnamed: 102  \
# Code du département                                   ...
# 2A                           220        220      220  ...           220
# 2B                           325        325      325  ...           325
# ZN                           297        297      297  ...           297
# ZX                            26         26       26  ...            26
# ZZ                           210        210      210  ...           210
#
#                      Unnamed: 103  Unnamed: 104  code_commune  code  \
# Code du département
# 2A                            220           220           220   220
# 2B                            325           325           325   325
# ZN                            297           297           297   297
# ZX                             26            26            26    26
# ZZ                            210           210           210   210
#
#                      commune_miom  libelle_departement_miom  id_brut_miom  \
# Code du département
# 2A                            220                       220           220
# 2B                            325                       325           325
# ZN                            297                       297           297
# ZX                             26                        26            26
# ZZ                            210                       210           210
#
#                      departement_miom  id_clean_miom
# Code du département
# 2A                                220            220
# 2B                                325            325
# ZN                                297            297
# ZX                                 26             26
# ZZ                                210            210
#
# [5 rows x 111 columns]

# %% [markdown]
# ## Matching

# %% [markdown]
# ### Y a-t-il des dupliqués ?

# %%
duplicates_reu = df_bv[df_bv['id_brut_reu'].duplicated(keep=False)]
duplicates_reu
# Out:
# Empty DataFrame
# Columns: [id_brut_reu, id_brut_insee, code_commune, code, libelle_reu, num_voie_reu, voie_reu, cp_reu, commune_reu, nb_adresses_initial, nb_adresses_final, departement]
# Index: []

# %%
duplicates_miom = df_bv_miom[df_bv_miom['id_clean_miom'].duplicated(keep=False)]
duplicates_miom
# Out:
# Empty DataFrame
# Columns: [id_brut_miom, id_clean_miom, code_commune, code, commune_miom, departement_miom, libelle_departement_miom]
# Index: []

# %% [markdown]
# ### Jointure

# %%
df_inner_matching = pd.merge(df_bv, df_bv_miom,
                           on=[
                               'code', 'code_commune'
                           ],
                           how='inner')

# %%
print(len(df_inner_matching))

df_inner_matching.head()
# Out:
# 66375
#   id_brut_reu id_brut_insee code_commune code              libelle_reu  \
# 0     01001_1        1001_1        01001    1                 bureau 1
# 1     01002_1        1002_1        01002    1                   mairie
# 2     01004_1        1004_1        01004    1           b1 espace 1500
# 3     01004_2        1004_2        01004    2           b2 espace 1500
# 4     01004_3        1004_3        01004    3  b3 chateau des echelles
#
#   num_voie_reu            voie_reu cp_reu            commune_reu  \
# 0                  Salle des fêtes  01400  abergement clemenciat
# 1            1  Place de la Mairie  01640  l abergement de varey
# 2                 AVENUE LEON BLUM  01500      amberieu en bugey
# 3                 AVENUE LEON BLUM  01500      amberieu en bugey
# 4                   RUE DES ARENES  01500      amberieu en bugey
#
#    nb_adresses_initial  nb_adresses_final departement id_brut_miom  \
# 0                  448              448.0          01   01001_0001
# 1                  157              143.0          01   01002_0001
# 2                  633              630.0          01   01004_0001
# 3                  640              638.0          01   01004_0002
# 4                  736              730.0          01   01004_0003
#
#   id_clean_miom             commune_miom departement_miom  \
# 0       01001_1  L'Abergement-Clémenciat               01
# 1       01002_1    L'Abergement-de-Varey               01
# 2       01004_1        Ambérieu-en-Bugey               01
# 3       01004_2        Ambérieu-en-Bugey               01
# 4       01004_3        Ambérieu-en-Bugey               01
#
#   libelle_departement_miom
# 0                      Ain
# 1                      Ain
# 2                      Ain
# 3                      Ain
# 4                      Ain

# %% [markdown]
# ## Etude des rebuts

# %%
rebuts_reu = df_bv[~df_bv.id_brut_reu.isin(df_inner_matching.id_brut_reu)]
len(rebuts_reu)
# Out:
# 2464

# %%
rebuts_reu.head()
# Out:
#       id_brut_reu id_brut_insee code_commune code         libelle_reu  \
# 1543      02821_0        2821_0        02821         bureau de vote 1
# 2086  04079_1 - 1      4079_1 1        04079  1 1   batiment communal
# 2096  04090_1 - 1      4090_1 1        04090  1 1      hotel de ville
# 2103  04095_1 - 1      4095_1 1        04095  1 1         m a i r i e
# 2106  04099_1 - 2      4099_1 2        04099  1 2  salle paul germain
#
#      num_voie_reu                                  voie_reu cp_reu  \
# 1543            1                              Rue Emptinne  02870
# 2086               Maison des Associations et de la Culture  04160
# 2096                                               LA PLACE  04240
# 2103            1                                 Le perron  04150
# 2106                                       rue du Cimetière  04170
#
#      commune_reu  nb_adresses_initial  nb_adresses_final departement
# 1543     vivaise                  323              323.0          02
# 2086    l escale                  699              689.0          04
# 2096  le fugeret                  122               74.0          04
# 2103  hospitalet                   71               68.0          04
# 2106  lambruisse                   72               72.0          04

# %%
rebuts_miom = df_bv_miom[~df_bv_miom.id_brut_miom.isin(df_inner_matching.id_brut_miom)]
len(rebuts_miom)
# Out:
# 3307

# %%
rebuts_miom.head()
# Out:
#      id_brut_miom id_clean_miom code_commune code     commune_miom  \
# 104    01053_0020      01053_20        01053   20  Bourg-en-Bresse
# 1054   02408_0020      02408_20        02408   20             Laon
# 1545   02821_0001       02821_1        02821    1          Vivaise
# 1838   03190_0020      03190_20        03190   20          Moulins
# 2083   04070_0013      04070_13        04070   13  Digne-les-Bains
#
#      departement_miom libelle_departement_miom
# 104                01                      Ain
# 1054               02                    Aisne
# 1545               02                    Aisne
# 1838               03                   Allier
# 2083               04  Alpes-de-Haute-Provence

# %% [markdown]
# ## Rattraper rebuts seuls dans leur commune

# %%
nb_codes_communes_reu = rebuts_reu["code_commune"].value_counts()
nb_codes_communes_miom = rebuts_miom["code_commune"].value_counts()

codes_communes_bv_seuls = nb_codes_communes_reu[nb_codes_communes_reu == 1].index
codes_communes_bv_miom_seuls = nb_codes_communes_miom[nb_codes_communes_miom == 1].index

# %%
rebuts_reu_seuls = rebuts_reu[rebuts_reu["code_commune"].isin(codes_communes_bv_seuls)]
len(rebuts_reu_seuls)
# Out:
# 458

# %%
rebuts_miom_seuls = rebuts_miom[rebuts_miom["code_commune"].isin(codes_communes_bv_miom_seuls)]
len(rebuts_miom_seuls)
# Out:
# 748

# %%
rebuts_rattrapables = pd.merge(rebuts_reu_seuls, rebuts_miom_seuls,
                           on=[
                               'code_commune'
                           ],
                           how='inner')

# %%
print(len(rebuts_rattrapables))

rebuts_rattrapables.head()
# Out:
# 427
#    id_brut_reu id_brut_insee code_commune code_x         libelle_reu  \
# 0      02821_0        2821_0        02821           bureau de vote 1
# 1  04079_1 - 1      4079_1 1        04079    1 1   batiment communal
# 2  04090_1 - 1      4090_1 1        04090    1 1      hotel de ville
# 3  04095_1 - 1      4095_1 1        04095    1 1         m a i r i e
# 4  04099_1 - 2      4099_1 2        04099    1 2  salle paul germain
#
#   num_voie_reu                                  voie_reu cp_reu commune_reu  \
# 0            1                              Rue Emptinne  02870     vivaise
# 1               Maison des Associations et de la Culture  04160    l escale
# 2                                               LA PLACE  04240  le fugeret
# 3            1                                 Le perron  04150  hospitalet
# 4                                       rue du Cimetière  04170  lambruisse
#
#    nb_adresses_initial  nb_adresses_final departement id_brut_miom  \
# 0                  323              323.0          02   02821_0001
# 1                  699              689.0          04   04079_0001
# 2                  122               74.0          04   04090_0001
# 3                   71               68.0          04   04095_0001
# 4                   72               72.0          04   04099_0001
#
#   id_clean_miom code_y  commune_miom departement_miom libelle_departement_miom
# 0       02821_1      1       Vivaise               02                    Aisne
# 1       04079_1      1      L'Escale               04  Alpes-de-Haute-Provence
# 2       04090_1      1    Le Fugeret               04  Alpes-de-Haute-Provence
# 3       04095_1      1  L'Hospitalet               04  Alpes-de-Haute-Provence
# 4       04099_1      1    Lambruisse               04  Alpes-de-Haute-Provence

# %%
df_matching = pd.concat([df_inner_matching, rebuts_rattrapables], axis=0).drop_duplicates()

# %% [markdown]
# ## Etude des vrais rebuts

# %% [markdown]
# ### Premières observations

# %%
vrais_rebuts_reu = rebuts_reu[~rebuts_reu.id_brut_reu.isin(rebuts_rattrapables.id_brut_reu)].sort_values('code_commune')
vrais_rebuts_reu
# Out:
#        id_brut_reu id_brut_insee code_commune code  \
# 3098     06088_533          None        06088  533
# 3524   07045_1 - 2      7045_1 2        07045  1 2
# 3525   07045_1 - 3      7045_1 3        07045  1 3
# 3739   07230_1 - 1      7230_1 1        07230  1 1
# 4584        09123_          None        09123
# ...            ...           ...          ...  ...
# 62355    90010_B-1     90010_B 1        90010   b1
# 62354    90010_A-2     90010_A 2        90010   a2
# 62353    90010_A-1     90010_A 1        90010   a1
# 62365    90010_E-3     90010_E 3        90010   e3
# 62380    90010_N-2     90010_N 2        90010   n2
#
#                            libelle_reu num_voie_reu  \
# 3098                   philippe seguin            6
# 3524                   salle des fetes           10
# 3525                   salle des fetes           10
# 3739                            mairie
# 4584                            unique
# ...                                ...          ...
# 62355    ecole elementaire victor hugo            3
# 62354                  salle des fetes
# 62353                   hotel de ville
# 62365  ecole maternelle raymond aubert           19
# 62380    maison de quartier des forges            3
#
#                                  voie_reu cp_reu                commune_reu  \
# 3098                     RUE ALFRED BINET  06000                       nice
# 3524                      Rue de l'église  07450                     burzet
# 3525                      Rue de l'église  07450                     burzet
# 3739                           LE VILLAGE  07200  saint etienne de boulogne
# 4584                               Mairie  09350                     fornex
# ...                                   ...    ...                        ...
# 62355                  rue François Géant  90000                    belfort
# 62354              Place de la République  90000                    belfort
# 62353                       Place d'Armes  90000                    belfort
# 62365  rue de la Première Armée Française  90000                    belfort
# 62380                    rue de Marseille  90000                    belfort
#
#        nb_adresses_initial  nb_adresses_final departement
# 3098                    65               65.0          06
# 3524                     6                6.0          07
# 3525                   345              337.0          07
# 3739                    96               70.0          07
# 4584                     1                1.0          09
# ...                    ...                ...         ...
# 62355                  267              259.0          90
# 62354                  181              176.0          90
# 62353                  228              225.0          90
# 62365                  152              151.0          90
# 62380                  422              419.0          90
#
# [2037 rows x 12 columns]

# %%
vrais_rebuts_miom = rebuts_miom[~rebuts_miom.id_brut_miom.isin(rebuts_rattrapables.id_brut_miom)].sort_values('code_commune')
vrais_rebuts_miom
# Out:
#       id_brut_miom id_clean_miom code_commune code      commune_miom  \
# 104     01053_0020      01053_20        01053   20   Bourg-en-Bresse
# 1054    02408_0020      02408_20        02408   20              Laon
# 1838    03190_0020      03190_20        03190   20           Moulins
# 2083    04070_0013      04070_13        04070   13   Digne-les-Bains
# 2150    04126_0001       04126_1        04126    1          Montclar
# ...            ...           ...          ...  ...               ...
# 69677   ZZ229_0001       ZZ229_1        ZZ229    1            Zurich
# 69678   ZZ231_0001       ZZ231_1        ZZ231    1            Taipei
# 69679   ZZ233_0001       ZZ233_1        ZZ233    1      Nour-Soultan
# 69680   ZZ234_0001       ZZ234_1        ZZ234    1         Monterrey
# 69681   ZZ235_0001       ZZ235_1        ZZ235    1  Bahamas (Nassau)
#
#       departement_miom         libelle_departement_miom
# 104                 01                              Ain
# 1054                02                            Aisne
# 1838                03                           Allier
# 2083                04          Alpes-de-Haute-Provence
# 2150                04          Alpes-de-Haute-Provence
# ...                ...                              ...
# 69677               ZZ  Français établis hors de France
# 69678               ZZ  Français établis hors de France
# 69679               ZZ  Français établis hors de France
# 69680               ZZ  Français établis hors de France
# 69681               ZZ  Français établis hors de France
#
# [2880 rows x 7 columns]

# %%
vrais_rebuts_reu[vrais_rebuts_reu["code_commune"].apply(lambda x: x.isnumeric() and int(x[:2]) < 97)]
# Out:
#        id_brut_reu id_brut_insee code_commune code  \
# 3098     06088_533          None        06088  533
# 3524   07045_1 - 2      7045_1 2        07045  1 2
# 3525   07045_1 - 3      7045_1 3        07045  1 3
# 3739   07230_1 - 1      7230_1 1        07230  1 1
# 4584        09123_          None        09123
# ...            ...           ...          ...  ...
# 62355    90010_B-1     90010_B 1        90010   b1
# 62354    90010_A-2     90010_A 2        90010   a2
# 62353    90010_A-1     90010_A 1        90010   a1
# 62365    90010_E-3     90010_E 3        90010   e3
# 62380    90010_N-2     90010_N 2        90010   n2
#
#                            libelle_reu num_voie_reu  \
# 3098                   philippe seguin            6
# 3524                   salle des fetes           10
# 3525                   salle des fetes           10
# 3739                            mairie
# 4584                            unique
# ...                                ...          ...
# 62355    ecole elementaire victor hugo            3
# 62354                  salle des fetes
# 62353                   hotel de ville
# 62365  ecole maternelle raymond aubert           19
# 62380    maison de quartier des forges            3
#
#                                  voie_reu cp_reu                commune_reu  \
# 3098                     RUE ALFRED BINET  06000                       nice
# 3524                      Rue de l'église  07450                     burzet
# 3525                      Rue de l'église  07450                     burzet
# 3739                           LE VILLAGE  07200  saint etienne de boulogne
# 4584                               Mairie  09350                     fornex
# ...                                   ...    ...                        ...
# 62355                  rue François Géant  90000                    belfort
# 62354              Place de la République  90000                    belfort
# 62353                       Place d'Armes  90000                    belfort
# 62365  rue de la Première Armée Française  90000                    belfort
# 62380                    rue de Marseille  90000                    belfort
#
#        nb_adresses_initial  nb_adresses_final departement
# 3098                    65               65.0          06
# 3524                     6                6.0          07
# 3525                   345              337.0          07
# 3739                    96               70.0          07
# 4584                     1                1.0          09
# ...                    ...                ...         ...
# 62355                  267              259.0          90
# 62354                  181              176.0          90
# 62353                  228              225.0          90
# 62365                  152              151.0          90
# 62380                  422              419.0          90
#
# [2033 rows x 12 columns]

# %%
vrais_rebuts_miom[vrais_rebuts_miom["code_commune"].apply(lambda x: x.isnumeric() and int(x[:2]) < 97)]
# Out:
#       id_brut_miom id_clean_miom code_commune code        commune_miom  \
# 104     01053_0020      01053_20        01053   20     Bourg-en-Bresse
# 1054    02408_0020      02408_20        02408   20                Laon
# 1838    03190_0020      03190_20        03190   20             Moulins
# 2083    04070_0013      04070_13        04070   13     Digne-les-Bains
# 2150    04126_0001       04126_1        04126    1            Montclar
# ...            ...           ...          ...  ...                 ...
# 62836   91228_0034      91228_34        91228   34  Evry-Courcouronnes
# 64173   92050_0050      92050_50        92050   50            Nanterre
# 64598   93008_0023      93008_23        93008   23             Bobigny
# 65517   94028_0046      94028_46        94028   46             Créteil
# 66697   95500_0022      95500_22        95500   22            Pontoise
#
#       departement_miom libelle_departement_miom
# 104                 01                      Ain
# 1054                02                    Aisne
# 1838                03                   Allier
# 2083                04  Alpes-de-Haute-Provence
# 2150                04  Alpes-de-Haute-Provence
# ...                ...                      ...
# 62836               91                  Essonne
# 64173               92           Hauts-de-Seine
# 64598               93        Seine-Saint-Denis
# 65517               94             Val-de-Marne
# 66697               95               Val-d'Oise
#
# [2087 rows x 7 columns]

# %%
vrais_rebuts_reu[vrais_rebuts_reu["code_commune"].apply(lambda x: x.isnumeric() and int(x[:2]) >= 97)]
# Out:
# Empty DataFrame
# Columns: [id_brut_reu, id_brut_insee, code_commune, code, libelle_reu, num_voie_reu, voie_reu, cp_reu, commune_reu, nb_adresses_initial, nb_adresses_final, departement]
# Index: []

# %%
vrais_rebuts_miom[vrais_rebuts_miom["code_commune"].apply(lambda x: x.isnumeric() and int(x[:2]) >= 97)]
# Out:
#       id_brut_miom id_clean_miom code_commune code    commune_miom  \
# 66996   ZA105_0013      97105_13        97105   13     Basse-Terre
# 67411   ZB209_0061      97209_61        97209   61  Fort-de-France
# 67681   ZC302_0033      97302_33        97302   33         Cayenne
# 68123   ZD411_0134     97411_134        97411  134     Saint-Denis
# 68831   ZM611_0183     97611_183        97611  183       Mamoudzou
# ...            ...           ...          ...  ...             ...
# 69436   ZP757_0005       98757_5        98757    5          Ua-Pou
# 69437   ZP757_0006       98757_6        98757    6          Ua-Pou
# 69438   ZP758_0001       98758_1        98758    1          Uturoa
# 69439   ZP758_0002       98758_2        98758    2          Uturoa
# 69440   ZP758_0003       98758_3        98758    3          Uturoa
#
#       departement_miom libelle_departement_miom
# 66996              971               Guadeloupe
# 67411              972               Martinique
# 67681              973                   Guyane
# 68123              974               La Réunion
# 68831              976                  Mayotte
# ...                ...                      ...
# 69436              987      Polynésie française
# 69437              987      Polynésie française
# 69438              987      Polynésie française
# 69439              987      Polynésie française
# 69440              987      Polynésie française
#
# [256 rows x 7 columns]

# %%
vrais_rebuts_reu[vrais_rebuts_reu["code_commune"].apply(lambda x: not(x.isnumeric()))]
# Out:
#        id_brut_reu id_brut_insee code_commune code           libelle_reu  \
# 17292      2A130_5          None        2A130    5    bureau de vote n 5
# 17451      2B042_5          None        2B042    5  centre administratif
# 17552  2B166_1 - 1     2B166_1 1        2B166  1 1      mairie village 1
# 17553  2B166_2 - 3     2B166_2 3        2B166  2 3       mairie annexe 2
#
#       num_voie_reu                     voie_reu cp_reu      commune_reu  \
# 17292                MAIRIE ANNEXE DE PORTICCIO  20166  grosseto prugna
# 17451                            Salle du Patio  20290            borgo
# 17552           54            PLACE DE L'EGLISE  20290            monte
# 17553                                            20290            monte
#
#        nb_adresses_initial  nb_adresses_final departement
# 17292                  432              415.0          2A
# 17451                  724              721.0          2B
# 17552                  105               78.0          2B
# 17553                  174              161.0          2B

# %%
vrais_rebuts_miom[vrais_rebuts_miom["code_commune"].apply(lambda x: not(x.isnumeric()))]
# Out:
#       id_brut_miom id_clean_miom code_commune code      commune_miom  \
# 11149   2A004_0042      2A004_42        2A004   42           Ajaccio
# 11381   2B033_0027      2B033_27        2B033   27            Bastia
# 11495   2B166_0002       2B166_2        2B166    2             Monte
# 11494   2B166_0001       2B166_1        2B166    1             Monte
# 68894   ZN801_0001       ZN801_1        ZN801    1             Belep
# ...            ...           ...          ...  ...               ...
# 69677   ZZ229_0001       ZZ229_1        ZZ229    1            Zurich
# 69678   ZZ231_0001       ZZ231_1        ZZ231    1            Taipei
# 69679   ZZ233_0001       ZZ233_1        ZZ233    1      Nour-Soultan
# 69680   ZZ234_0001       ZZ234_1        ZZ234    1         Monterrey
# 69681   ZZ235_0001       ZZ235_1        ZZ235    1  Bahamas (Nassau)
#
#       departement_miom         libelle_departement_miom
# 11149               2A                     Corse-du-Sud
# 11381               2B                      Haute-Corse
# 11495               2B                      Haute-Corse
# 11494               2B                      Haute-Corse
# 68894               ZN               Nouvelle-Calédonie
# ...                ...                              ...
# 69677               ZZ  Français établis hors de France
# 69678               ZZ  Français établis hors de France
# 69679               ZZ  Français établis hors de France
# 69680               ZZ  Français établis hors de France
# 69681               ZZ  Français établis hors de France
#
# [537 rows x 7 columns]

# %% [markdown]
# ### Les rebuts sont-ils dans les mêmes communes d'un côté et de l'autre ?

# %%
vrais_rebuts_reu_dans_communes_avec_miom = vrais_rebuts_reu[vrais_rebuts_reu["code_commune"].isin(set(vrais_rebuts_miom["code_commune"]))]
vrais_rebuts_miom_dans_communes_avec_reu = vrais_rebuts_miom[vrais_rebuts_miom["code_commune"].isin(set(vrais_rebuts_reu["code_commune"]))]

# %%
vrais_rebuts_reu_dans_communes_avec_miom
# Out:
#         id_brut_reu id_brut_insee code_commune code  \
# 3524    07045_1 - 2      7045_1 2        07045  1 2
# 3525    07045_1 - 3      7045_1 3        07045  1 3
# 4959   10112_01 - 1    10112_01 1        10112  1 1
# 4960   10112_01 - 2    10112_01 2        10112  1 2
# 5295      10387_304     10387_304        10387  304
# ...             ...           ...          ...  ...
# 62355     90010_B-1     90010_B 1        90010   b1
# 62354     90010_A-2     90010_A 2        90010   a2
# 62353     90010_A-1     90010_A 1        90010   a1
# 62365     90010_E-3     90010_E 3        90010   e3
# 62380     90010_N-2     90010_N 2        90010   n2
#
#                            libelle_reu num_voie_reu  \
# 3524                   salle des fetes           10
# 3525                   salle des fetes           10
# 4959          salle de la petite ecole
# 4960          salle de la petite ecole
# 5295             vassaules 2eme bureau
# ...                                ...          ...
# 62355    ecole elementaire victor hugo            3
# 62354                  salle des fetes
# 62353                   hotel de ville
# 62365  ecole maternelle raymond aubert           19
# 62380    maison de quartier des forges            3
#
#                                  voie_reu cp_reu commune_reu  \
# 3524                      Rue de l'église  07450      burzet
# 3525                      Rue de l'église  07450      burzet
# 4959                                       00000
# 4960                                       00000
# 5295               139 rue Etienne Pédron  10000      troyes
# ...                                   ...    ...         ...
# 62355                  rue François Géant  90000     belfort
# 62354              Place de la République  90000     belfort
# 62353                       Place d'Armes  90000     belfort
# 62365  rue de la Première Armée Française  90000     belfort
# 62380                    rue de Marseille  90000     belfort
#
#        nb_adresses_initial  nb_adresses_final departement
# 3524                     6                6.0          07
# 3525                   345              337.0          07
# 4959                     1                1.0          10
# 4960                    78               77.0          10
# 5295                   428              426.0          10
# ...                    ...                ...         ...
# 62355                  267              259.0          90
# 62354                  181              176.0          90
# 62353                  228              225.0          90
# 62365                  152              151.0          90
# 62380                  422              419.0          90
#
# [318 rows x 12 columns]

# %%
vrais_rebuts_miom_dans_communes_avec_reu
# Out:
#       id_brut_miom id_clean_miom code_commune code commune_miom  \
# 3529    07045_0001       07045_1        07045    1       Burzet
# 4964    10112_0001       10112_1        10112    1   Coussegrey
# 5300    10387_0029      10387_29        10387   29       Troyes
# 5301    10387_0001       10387_1        10387    1       Troyes
# 5302    10387_0002       10387_2        10387    2       Troyes
# ...            ...           ...          ...  ...          ...
# 62409   90010_0009       90010_9        90010    9      Belfort
# 62410   90010_0010      90010_10        90010   10      Belfort
# 62411   90010_0011      90010_11        90010   11      Belfort
# 62412   90010_0012      90010_12        90010   12      Belfort
# 62407   90010_0007       90010_7        90010    7      Belfort
#
#       departement_miom libelle_departement_miom
# 3529                07                  Ardèche
# 4964                10                     Aube
# 5300                10                     Aube
# 5301                10                     Aube
# 5302                10                     Aube
# ...                ...                      ...
# 62409               90    Territoire de Belfort
# 62410               90    Territoire de Belfort
# 62411               90    Territoire de Belfort
# 62412               90    Territoire de Belfort
# 62407               90    Territoire de Belfort
#
# [316 rows x 7 columns]

# %% [markdown]
# ### Rebuts liés aux arrondissements

# %% [markdown]
# #### Premières observations

# %%
rebuts_reu_arrondissements = vrais_rebuts_reu[vrais_rebuts_reu["departement"].isin(["13", "69", "75"])]
len(rebuts_reu_arrondissements)
# Out:
# 1692

# %%
rebuts_miom_arrondissements = vrais_rebuts_miom[vrais_rebuts_miom["departement_miom"].isin(["13", "69", "75"])]
len(rebuts_miom_arrondissements)
# Out:
# 1695

# %%
rebuts_reu_communes_differentes_hors_arrondissements = vrais_rebuts_reu[~(
    vrais_rebuts_reu['id_brut_reu'].isin(set(vrais_rebuts_reu_dans_communes_avec_miom['id_brut_reu'])) |
    vrais_rebuts_reu['departement'].isin(["13", "69", "75"])
)]

len(rebuts_reu_communes_differentes_hors_arrondissements)
# Out:
# 37

# %%
vrais_rebuts_miom_metropole = vrais_rebuts_miom[vrais_rebuts_miom["code_commune"].apply(lambda x: x.isnumeric() and int(x[:2]) < 97)]

rebuts_miom_communes_differentes_hors_arrondissements = vrais_rebuts_miom_metropole[~(
    vrais_rebuts_miom_metropole['id_brut_miom'].isin(set(vrais_rebuts_miom_dans_communes_avec_reu['id_brut_miom'])) |
    vrais_rebuts_miom_metropole['departement_miom'].isin(["13", "69", "75"])
)]

len(rebuts_miom_communes_differentes_hors_arrondissements)
# Out:
# 87

# %% [markdown]
# #### Marseille

# %%
rebuts_reu_marseille = vrais_rebuts_reu[vrais_rebuts_reu["departement"] == '13']
rebuts_reu_marseille
# Out:
#      id_brut_reu id_brut_insee code_commune  code  \
# 6746   13035_B05     13035_B05        13035   b05
# 6745   13035_B04     13035_B04        13035   b04
# 6742   13035_B01     13035_B01        13035   b01
# 6743   13035_B02     13035_B02        13035   b02
# 6744   13035_B03     13035_B03        13035   b03
# ...          ...           ...          ...   ...
# 7775  13216_1608    13216_1608        13216  1608
# 7774  13216_1607    13216_1607        13216  1607
# 7773  13216_1606    13216_1606        13216  1606
# 7772  13216_1602    13216_1602        13216  1602
# 7776  13216_1609    13216_1609        13216  1609
#
#                        libelle_reu num_voie_reu                   voie_reu  \
# 6746     bureau 5 salle de la gare                       Avenue de la Gare
# 6745    bureau 4 ecole trecasteaux               Faubourg de la Libération
# 6742       bureau 1 moulin alcazar                            Place Thiers
# 6743         bureau 2 ecole gilous               Avenue de la Guillaumette
# 6744    bureau 3 foyer du 3eme age                            Place Monier
# ...                            ...          ...                        ...
# 7775         e elem saint henri ii           14                 PCE RAPHEL
# 7774          e elem saint henri i           95               RUE RABELAIS
# 7773          e elem saint henri i           95               RUE RABELAIS
# 7772  e elem saint andre condorcet   ENTREE 430           BD HENRI BARNIER
# 7776         e elem saint henri ii           14                 PCE RAPHEL
#
#      cp_reu commune_reu  nb_adresses_initial  nb_adresses_final departement
# 6746  13430   eyguieres                  667              649.0          13
# 6745  13430   eyguieres                  612              611.0          13
# 6742  13430   eyguieres                  534              529.0          13
# 6743  13430   eyguieres                  705              699.0          13
# 6744  13430   eyguieres                  506              501.0          13
# ...     ...         ...                  ...                ...         ...
# 7775  13016   marseille                  593              586.0          13
# 7774  13016   marseille                  411              402.0          13
# 7773  13016   marseille                  393              382.0          13
# 7772  13016   marseille                  598              586.0          13
# 7776  13016   marseille                  497              492.0          13
#
# [490 rows x 12 columns]

# %%
rebuts_miom_marseille = vrais_rebuts_miom[vrais_rebuts_miom["departement_miom"] == '13']
rebuts_miom_marseille
# Out:
#      id_brut_miom id_clean_miom code_commune  code  \
# 6749   13035_0001       13035_1        13035     1
# 6750   13035_0002       13035_2        13035     2
# 6751   13035_0003       13035_3        13035     3
# 6752   13035_0004       13035_4        13035     4
# 6753   13035_0005       13035_5        13035     5
# ...           ...           ...          ...   ...
# 7088   13055_1343    13055_1343        13055  1343
# 7440   13061_0001       13061_1        13061     1
# 7650   13102_0001       13102_1        13102     1
# 7651   13102_0002       13102_2        13102     2
# 7652   13102_0003       13102_3        13102     3
#
#                     commune_miom departement_miom libelle_departement_miom
# 6749                   Eyguières               13         Bouches-du-Rhône
# 6750                   Eyguières               13         Bouches-du-Rhône
# 6751                   Eyguières               13         Bouches-du-Rhône
# 6752                   Eyguières               13         Bouches-du-Rhône
# 6753                   Eyguières               13         Bouches-du-Rhône
# ...                          ...              ...                      ...
# 7088                   Marseille               13         Bouches-du-Rhône
# 7440  Saint-Pierre-de-Mézoargues               13         Bouches-du-Rhône
# 7650              Saint-Victoret               13         Bouches-du-Rhône
# 7651              Saint-Victoret               13         Bouches-du-Rhône
# 7652              Saint-Victoret               13         Bouches-du-Rhône
#
# [490 rows x 7 columns]

# %%
rebuts_reu_marseille['code_commune'] = rebuts_reu_marseille['code_commune'].apply(
    lambda x: '13055' if x[2] == '2' else x
)

rebuts_reu_marseille[rebuts_reu_marseille[['code_commune', 'code']].duplicated(keep=False)]
# Out:
# /tmp/ipykernel_775/2554710340.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rebuts_reu_marseille['code_commune'] = rebuts_reu_marseille['code_commune'].apply(
# Empty DataFrame
# Columns: [id_brut_reu, id_brut_insee, code_commune, code, libelle_reu, num_voie_reu, voie_reu, cp_reu, commune_reu, nb_adresses_initial, nb_adresses_final, departement]
# Index: []

# %%
rattrapage_rebuts_marseille = pd.merge(rebuts_reu_marseille, rebuts_miom_marseille,
                           on=[
                               'code', 'code_commune'
                           ],
                           how='inner')

len(rattrapage_rebuts_marseille)
# Out:
# 480

# %% [markdown]
# #### Lyon

# %%
rebuts_reu_lyon = vrais_rebuts_reu[vrais_rebuts_reu["departement"] == '69']
rebuts_reu_lyon
# Out:
#       id_brut_reu id_brut_insee code_commune code  \
# 48263   69381_113     69381_113        69381  113
# 48262   69381_112     69381_112        69381  112
# 48264   69381_114     69381_114        69381  114
# 48266   69381_116     69381_116        69381  116
# 48267   69381_117     69381_117        69381  117
# ...           ...           ...          ...  ...
# 48527   69389_903     69389_903        69389  903
# 48526   69389_902     69389_902        69389  902
# 48525   69389_901     69389_901        69389  901
# 48539   69389_915     69389_915        69389  915
# 48529   69389_905     69389_905        69389  905
#
#                          libelle_reu num_voie_reu                    voie_reu  \
# 48263          ecole robert doisneau            1         rue Sergent Blandan
# 48262          ecole robert doisneau            1         rue Sergent Blandan
# 48264          ecole robert doisneau            1         rue Sergent Blandan
# 48266     groupe scolaire raoul dufy            4               rue Vaucanson
# 48267       ecole tables claudiennes            2  rue des Tables Claudiennes
# ...                              ...          ...                         ...
# 48527                mairie du 9 eme            6             place du Marché
# 48526                mairie du 9 eme            6             place du Marché
# 48525                mairie du 9 eme            6             place du Marché
# 48539         gymnase audrey hepburn            5           rue Laure Diebold
# 48529  groupe scolaire chapeau rouge           45        rue du Chapeau Rouge
#
#       cp_reu commune_reu  nb_adresses_initial  nb_adresses_final departement
# 48263  69001        lyon                  227              226.0          69
# 48262  69001        lyon                  297              296.0          69
# 48264  69001        lyon                  317              309.0          69
# 48266  69001        lyon                  214              212.0          69
# 48267  69001        lyon                  228              227.0          69
# ...      ...         ...                  ...                ...         ...
# 48527  69009        lyon                  314              280.0          69
# 48526  69009        lyon                  180              180.0          69
# 48525  69009        lyon                  328              325.0          69
# 48539  69009        lyon                  246              236.0          69
# 48529  69009        lyon                  134              134.0          69
#
# [304 rows x 12 columns]

# %%
rebuts_miom_lyon = vrais_rebuts_miom[vrais_rebuts_miom["departement_miom"] == '69']
rebuts_miom_lyon
# Out:
#       id_brut_miom id_clean_miom code_commune code commune_miom  \
# 47820   69123_0820     69123_820        69123  820         Lyon
# 47819   69123_0810     69123_810        69123  810         Lyon
# 47816   69123_0807     69123_807        69123  807         Lyon
# 47818   69123_0809     69123_809        69123  809         Lyon
# 47817   69123_0808     69123_808        69123  808         Lyon
# ...            ...           ...          ...  ...          ...
# 47715   69123_0215     69123_215        69123  215         Lyon
# 47714   69123_0210     69123_210        69123  210         Lyon
# 47713   69123_0209     69123_209        69123  209         Lyon
# 47712   69123_0208     69123_208        69123  208         Lyon
# 47718   69123_0218     69123_218        69123  218         Lyon
#
#       departement_miom libelle_departement_miom
# 47820               69                    Rhône
# 47819               69                    Rhône
# 47816               69                    Rhône
# 47818               69                    Rhône
# 47817               69                    Rhône
# ...                ...                      ...
# 47715               69                    Rhône
# 47714               69                    Rhône
# 47713               69                    Rhône
# 47712               69                    Rhône
# 47718               69                    Rhône
#
# [305 rows x 7 columns]

# %%
rebuts_reu_lyon['code_commune'] = rebuts_reu_lyon['code_commune'].apply(
    lambda x: '69123' if x[2] == '3' else x
)

rebuts_reu_lyon[rebuts_reu_lyon[['code_commune', 'code']].duplicated(keep=False)]
# Out:
# /tmp/ipykernel_775/886085551.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rebuts_reu_lyon['code_commune'] = rebuts_reu_lyon['code_commune'].apply(
# Empty DataFrame
# Columns: [id_brut_reu, id_brut_insee, code_commune, code, libelle_reu, num_voie_reu, voie_reu, cp_reu, commune_reu, nb_adresses_initial, nb_adresses_final, departement]
# Index: []

# %%
rattrapage_rebuts_lyon = pd.merge(rebuts_reu_lyon, rebuts_miom_lyon,
                           on=[
                               'code', 'code_commune'
                           ],
                           how='inner')

len(rattrapage_rebuts_lyon)
# Out:
# 304

# %% [markdown]
# #### Paris

# %%
rebuts_reu_paris = vrais_rebuts_reu[vrais_rebuts_reu["departement"] == '75']
rebuts_reu_paris
# Out:
#       id_brut_reu id_brut_insee code_commune code  \
# 51646     75101_1       75101_1        75101    1
# 51647    75101_10      75101_10        75101   10
# 51648     75101_2       75101_2        75101    2
# 51649     75101_3       75101_3        75101    3
# 51650     75101_4       75101_4        75101    4
# ...           ...           ...          ...  ...
# 52492    75120_31      75120_31        75120   31
# 52491    75120_30      75120_30        75120   30
# 52490     75120_3       75120_3        75120    3
# 52489    75120_29      75120_29        75120   29
# 52488    75120_28      75120_28        75120   28
#
#                                             libelle_reu num_voie_reu  \
# 51646                   ex mairie du 1er arrondissement            4
# 51647                                 ecole elementaire           28
# 51648                                 ecole elementaire           19
# 51649                                  ecole maternelle            6
# 51650             mediatheque de la canopee la fontaine           10
# ...                                                 ...          ...
# 52492                                 ecole elementaire           20
# 52491                      college pierre mendes france           24
# 52490  etablissement scolaire saint germain de charonne            3
# 52489                                 ecole elementaire            4
# 52488                                  ecole maternelle            2
#
#                             voie_reu cp_reu commune_reu  nb_adresses_initial  \
# 51646                PLACE DU LOUVRE  75001       paris                  372
# 51647                     RUE CAMBON  75001       paris                  309
# 51648             RUE DE L'ARBRE SEC  75001       paris                  448
# 51649  RUE SAINT-GERMAIN L'AUXERROIS  75001       paris                  472
# 51650          PASSAGE DE LA CANOPEE  75001       paris                  382
# ...                              ...    ...         ...                  ...
# 52492                     RUE LE VAU  75020       paris                  502
# 52491                     RUE LE VAU  75020       paris                  419
# 52490               RUE DES PRAIRIES  75020       paris                  331
# 52489              RUE PIERRE FONCIN  75020       paris                  370
# 52488              RUE PIERRE FONCIN  75020       paris                  299
#
#        nb_adresses_final departement
# 51646              366.0          75
# 51647              307.0          75
# 51648              448.0          75
# 51649              466.0          75
# 51650              377.0          75
# ...                  ...         ...
# 52492              501.0          75
# 52491              416.0          75
# 52490              327.0          75
# 52489              172.0          75
# 52488              259.0          75
#
# [898 rows x 12 columns]

# %%
rebuts_miom_paris = vrais_rebuts_miom[vrais_rebuts_miom["departement_miom"] == '75']
rebuts_miom_paris
# Out:
#       id_brut_miom id_clean_miom code_commune  code commune_miom  \
# 52289   75056_1534    75056_1534        75056  1534        Paris
# 52288   75056_1533    75056_1533        75056  1533        Paris
# 52287   75056_1532    75056_1532        75056  1532        Paris
# 52286   75056_1531    75056_1531        75056  1531        Paris
# 52290   75056_1535    75056_1535        75056  1535        Paris
# ...            ...           ...          ...   ...          ...
# 51985   75056_2062    75056_2062        75056  2062        Paris
# 51984   75056_2061    75056_2061        75056  2061        Paris
# 51983   75056_2060    75056_2060        75056  2060        Paris
# 51982   75056_2059    75056_2059        75056  2059        Paris
# 51987   75056_2064    75056_2064        75056  2064        Paris
#
#       departement_miom libelle_departement_miom
# 52289               75                    Paris
# 52288               75                    Paris
# 52287               75                    Paris
# 52286               75                    Paris
# 52290               75                    Paris
# ...                ...                      ...
# 51985               75                    Paris
# 51984               75                    Paris
# 51983               75                    Paris
# 51982               75                    Paris
# 51987               75                    Paris
#
# [900 rows x 7 columns]

# %%
rebuts_reu_paris['code'] = rebuts_reu_paris['code'].apply(lambda x: "0" + x)
rebuts_reu_paris['code'] = rebuts_reu_paris['code_commune'].apply(lambda x: x[-2:]) + rebuts_reu_paris['code'].apply(lambda x: x[-2:])
rebuts_reu_paris['code'] = rebuts_reu_paris['code'].apply(lambda x: x[1:] if x[0] == '0' else x)

rebuts_reu_paris['code_commune'] = "75056"

rebuts_reu_paris[rebuts_reu_paris[['code_commune', 'code']].duplicated(keep=False)]
# Out:
# /tmp/ipykernel_775/3853486837.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rebuts_reu_paris['code'] = rebuts_reu_paris['code'].apply(lambda x: "0" + x)
# /tmp/ipykernel_775/3853486837.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rebuts_reu_paris['code'] = rebuts_reu_paris['code_commune'].apply(lambda x: x[-2:]) + rebuts_reu_paris['code'].apply(lambda x: x[-2:])
# /tmp/ipykernel_775/3853486837.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rebuts_reu_paris['code'] = rebuts_reu_paris['code'].apply(lambda x: x[1:] if x[0] == '0' else x)
# /tmp/ipykernel_775/3853486837.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rebuts_reu_paris['code_commune'] = "75056"
# Empty DataFrame
# Columns: [id_brut_reu, id_brut_insee, code_commune, code, libelle_reu, num_voie_reu, voie_reu, cp_reu, commune_reu, nb_adresses_initial, nb_adresses_final, departement]
# Index: []

# %%
rattrapage_rebuts_paris = pd.merge(rebuts_reu_paris, rebuts_miom_paris,
                           on=[
                               'code', 'code_commune'
                           ],
                           how='inner')

len(rattrapage_rebuts_paris)
# Out:
# 859

# %% [markdown]
# #### L'heure des résultats

# %%
df_matching = pd.concat([df_matching, rattrapage_rebuts_marseille, rattrapage_rebuts_lyon, rattrapage_rebuts_paris], axis=0).drop_duplicates()

# %%
len(df_matching)
# Out:
# 68445

# %%
vrais_rebuts_arrondissements_reu = rebuts_reu_arrondissements[
    ~rebuts_reu_arrondissements.id_brut_reu.isin(df_matching.id_brut_reu)
].sort_values('code_commune')

len(vrais_rebuts_arrondissements_reu)
# Out:
# 49

# %%
vrais_rebuts_arrondissements_miom = rebuts_miom_arrondissements[
    ~rebuts_miom_arrondissements.id_brut_miom.isin(df_matching.id_brut_miom)
].sort_values('code_commune')

len(vrais_rebuts_arrondissements_miom)
# Out:
# 52

# %% [markdown]
# ## Fin et matching manuel

# %% [markdown]
# ### Matching réussi

# %%
df_correspondance = df_matching[['id_brut_reu', 'id_brut_miom']]
len(df_correspondance)
# Out:
# 68445

# %%
df_bv_avec_correspondance = pd.merge(df_bv_originale, df_correspondance,
                           on=[
                               'id_brut_reu'
                           ],
                           how='inner')

len(df_bv_avec_correspondance)
# Out:
# 68445

# %%
df_bv_avec_correspondance.head()
# Out:
#   id_brut_reu id_brut_insee code_commune code              libelle_reu  \
# 0     01001_1        1001_1        01001    1                 bureau 1
# 1     01002_1        1002_1        01002    1                   mairie
# 2     01004_1        1004_1        01004    1           b1 espace 1500
# 3     01004_2        1004_2        01004    2           b2 espace 1500
# 4     01004_3        1004_3        01004    3  b3 chateau des echelles
#
#   num_voie_reu            voie_reu cp_reu            commune_reu  \
# 0                  Salle des fêtes  01400  abergement clemenciat
# 1            1  Place de la Mairie  01640  l abergement de varey
# 2                 AVENUE LEON BLUM  01500      amberieu en bugey
# 3                 AVENUE LEON BLUM  01500      amberieu en bugey
# 4                   RUE DES ARENES  01500      amberieu en bugey
#
#    nb_adresses_initial  nb_adresses_final id_brut_miom
# 0                  448              448.0   01001_0001
# 1                  157              143.0   01002_0001
# 2                  633              630.0   01004_0001
# 3                  640              638.0   01004_0002
# 4                  736              730.0   01004_0003

# %%
# df_bv_avec_correspondance.to_parquet("table_bv_avec_correspondances_miom.parquet", index=False)

# %% [markdown]
# ### Matching raté

# %%
matching_rate_reu = df_bv_originale[~df_bv_originale.id_brut_reu.isin(df_correspondance.id_brut_reu)].sort_values('id_brut_reu')

matching_rate_miom = df_bv_miom[~df_bv_miom.id_brut_miom.isin(df_correspondance.id_brut_miom)].sort_values('id_brut_miom')
matching_rate_miom = matching_rate_miom[matching_rate_miom['departement_miom'].apply(lambda x: x.isnumeric())]

# %%
matching_rate_reu
# Out:
#        id_brut_reu id_brut_insee code_commune code  \
# 3098     06088_533          None        06088  533
# 3524   07045_1 - 2      7045_1 2        07045  1 2
# 3525   07045_1 - 3      7045_1 3        07045  1 3
# 3739   07230_1 - 1      7230_1 1        07230  1 1
# 4584        09123_          None        09123
# ...            ...           ...          ...  ...
# 62376    90010_L-2     90010_L 2        90010  l 2
# 62377    90010_L-3     90010_L 3        90010  l 3
# 62378    90010_M-1     90010_M 1        90010  m 1
# 62379    90010_N-1     90010_N 1        90010  n 1
# 62380    90010_N-2     90010_N 2        90010  n 2
#
#                                      libelle_reu num_voie_reu  \
# 3098                             philippe seguin            6
# 3524                             salle des fetes           10
# 3525                             salle des fetes           10
# 3739                                      mairie
# 4584                                      unique
# ...                                          ...          ...
# 62376                ecole maternelle des barres            9
# 62377               ecole elementaire des barres           10
# 62378  ecole maternelle antoine de saint exupery
# 62379                            gymnase serzian
# 62380              maison de quartier des forges            3
#
#                   voie_reu cp_reu                commune_reu  \
# 3098      RUE ALFRED BINET  06000                       nice
# 3524       Rue de l'église  07450                     burzet
# 3525       Rue de l'église  07450                     burzet
# 3739            LE VILLAGE  07200  saint etienne de boulogne
# 4584                Mairie  09350                     fornex
# ...                    ...    ...                        ...
# 62376       Via d'Auxelles  90000                    belfort
# 62377  rue Jules Siegfried  90000                    belfort
# 62378       Rue de la Paix  90000                    belfort
# 62379          Rue Floréal  90000                    belfort
# 62380     rue de Marseille  90000                    belfort
#
#        nb_adresses_initial  nb_adresses_final
# 3098                    65               65.0
# 3524                     6                6.0
# 3525                   345              337.0
# 3739                    96               70.0
# 4584                     1                1.0
# ...                    ...                ...
# 62376                  276              274.0
# 62377                  278              278.0
# 62378                  183              183.0
# 62379                  260              259.0
# 62380                  422              419.0
#
# [394 rows x 11 columns]

# %%
matching_rate_miom
# Out:
#       id_brut_miom id_clean_miom code_commune code      commune_miom  \
# 104     01053_0020      01053_20        01053   20   Bourg-en-Bresse
# 1054    02408_0020      02408_20        02408   20              Laon
# 1838    03190_0020      03190_20        03190   20           Moulins
# 2083    04070_0013      04070_13        04070   13   Digne-les-Bains
# 2150    04126_0001       04126_1        04126    1          Montclar
# ...            ...           ...          ...  ...               ...
# 69437   ZP757_0006       98757_6        98757    6            Ua-Pou
# 69438   ZP758_0001       98758_1        98758    1            Uturoa
# 69439   ZP758_0002       98758_2        98758    2            Uturoa
# 69440   ZP758_0003       98758_3        98758    3            Uturoa
# 69445   ZW001_0001       98601_1        98601    1  Wallis-Et-Futuna
#
#       departement_miom libelle_departement_miom
# 104                 01                      Ain
# 1054                02                    Aisne
# 1838                03                   Allier
# 2083                04  Alpes-de-Haute-Provence
# 2150                04  Alpes-de-Haute-Provence
# ...                ...                      ...
# 69437              987      Polynésie française
# 69438              987      Polynésie française
# 69439              987      Polynésie française
# 69440              987      Polynésie française
# 69445              986         Wallis et Futuna
#
# [700 rows x 7 columns]

# %% [markdown]
# ### Matching à la main

# %%
matching_a_la_main_reu = matching_rate_reu[matching_rate_reu["code_commune"].isin(set(matching_rate_miom["code_commune"]))]
matching_a_la_main_miom = matching_rate_miom[matching_rate_miom["code_commune"].isin(set(matching_rate_reu["code_commune"]))]

# %%
matching_a_la_main_reu
# Out:
#         id_brut_reu id_brut_insee code_commune code  \
# 3524    07045_1 - 2      7045_1 2        07045  1 2
# 3525    07045_1 - 3      7045_1 3        07045  1 3
# 4959   10112_01 - 1    10112_01 1        10112  1 1
# 4960   10112_01 - 2    10112_01 2        10112  1 2
# 5279      10387_101     10387_101        10387  101
# ...             ...           ...          ...  ...
# 62376     90010_L-2     90010_L 2        90010  l 2
# 62377     90010_L-3     90010_L 3        90010  l 3
# 62378     90010_M-1     90010_M 1        90010  m 1
# 62379     90010_N-1     90010_N 1        90010  n 1
# 62380     90010_N-2     90010_N 2        90010  n 2
#
#                                      libelle_reu num_voie_reu  \
# 3524                             salle des fetes           10
# 3525                             salle des fetes           10
# 4959                    salle de la petite ecole
# 4960                    salle de la petite ecole
# 5279                   hotel de ville 1er bureau
# ...                                          ...          ...
# 62376                ecole maternelle des barres            9
# 62377               ecole elementaire des barres           10
# 62378  ecole maternelle antoine de saint exupery
# 62379                            gymnase serzian
# 62380              maison de quartier des forges            3
#
#                      voie_reu cp_reu commune_reu  nb_adresses_initial  \
# 3524          Rue de l'église  07450      burzet                    6
# 3525          Rue de l'église  07450      burzet                  345
# 4959                           00000                                1
# 4960                           00000                               78
# 5279   place Alexandre Israël  10000      troyes                  296
# ...                       ...    ...         ...                  ...
# 62376          Via d'Auxelles  90000     belfort                  276
# 62377     rue Jules Siegfried  90000     belfort                  278
# 62378          Rue de la Paix  90000     belfort                  183
# 62379             Rue Floréal  90000     belfort                  260
# 62380        rue de Marseille  90000     belfort                  422
#
#        nb_adresses_final
# 3524                 6.0
# 3525               337.0
# 4959                 1.0
# 4960                77.0
# 5279               295.0
# ...                  ...
# 62376              274.0
# 62377              278.0
# 62378              183.0
# 62379              259.0
# 62380              419.0
#
# [316 rows x 11 columns]

# %%
matching_a_la_main_miom
# Out:
#       id_brut_miom id_clean_miom code_commune code commune_miom  \
# 3529    07045_0001       07045_1        07045    1       Burzet
# 4964    10112_0001       10112_1        10112    1   Coussegrey
# 5301    10387_0001       10387_1        10387    1       Troyes
# 5302    10387_0002       10387_2        10387    2       Troyes
# 5303    10387_0003       10387_3        10387    3       Troyes
# ...            ...           ...          ...  ...          ...
# 62426   90010_0025      90010_25        90010   25      Belfort
# 62427   90010_0026      90010_26        90010   26      Belfort
# 62428   90010_0027      90010_27        90010   27      Belfort
# 62429   90010_0028      90010_28        90010   28      Belfort
# 62414   90010_0029      90010_29        90010   29      Belfort
#
#       departement_miom libelle_departement_miom
# 3529                07                  Ardèche
# 4964                10                     Aube
# 5301                10                     Aube
# 5302                10                     Aube
# 5303                10                     Aube
# ...                ...                      ...
# 62426               90    Territoire de Belfort
# 62427               90    Territoire de Belfort
# 62428               90    Territoire de Belfort
# 62429               90    Territoire de Belfort
# 62414               90    Territoire de Belfort
#
# [314 rows x 7 columns]

# %%
matching_a_la_main_reu.to_csv("matching_a_faire_a_la_main_reu.csv", index=False)
matching_a_la_main_miom.to_csv("matching_a_faire_a_la_main_miom.csv", index=False)

# %% [markdown]
# A partir des deux CSV générés (environ 300 lignes chacun), nous avons effectué un appariement à la main entre les deux référentiels lorsque les paires étaient évidentes. Cela concerne notamment :
#
# - Des bureaux de vote découpés en 2 d'un côté mais pas de l'autre (ex: "bureau 1" d'un côté et "bureau 1 1" et "bureau 1 2" de l'autre)
# - Des bureaux de vote pour lesquels un caractère précède les numéros de bureaux d'un côté mais pas de l'autre, les caractères observés étant entre autres "a", "b", "1", "10"
#
# Un CSV est alors retourné avec les identifiants des paires retrouvées dans les deux référentiels. Dans la pratique, près de la moitié des bv du REU envoyés en matching manuel ont pu être attribués à un bureau du MIOM.

# %%
os.system(f"mc cp s3/projet-adresses-reu/table_correspondance_a_la_main.csv table_correspondance_a_la_main.csv")

# %%
table_correspondance_a_la_main = pd.read_csv('table_correspondance_a_la_main.csv')

matching_fait_a_la_main = pd.merge(df_bv_originale, table_correspondance_a_la_main,
                           on=['id_brut_reu'],
                           how='inner')

len(matching_fait_a_la_main)
# Out:
# 270

# %% [markdown]
# ### Fin et sauvegarde

# %%
df_bv_finale_inner = pd.concat([df_bv_avec_correspondance, matching_fait_a_la_main], axis=0).drop_duplicates()
df_bv_finale_outer = pd.merge(df_bv_originale, df_bv_finale_inner,
                              how='left')

print(len(df_bv_finale_inner))
print(len(df_bv_finale_outer))
# Out:
# 68715
# 68839

# %%
df_bv_finale_outer.head(3)
# Out:
#   id_brut_reu id_brut_insee code_commune code     libelle_reu num_voie_reu  \
# 0     01001_1        1001_1        01001    1        bureau 1
# 1     01002_1        1002_1        01002    1          mairie            1
# 2     01004_1        1004_1        01004    1  b1 espace 1500
#
#              voie_reu cp_reu            commune_reu  nb_adresses_initial  \
# 0     Salle des fêtes  01400  abergement clemenciat                  448
# 1  Place de la Mairie  01640  l abergement de varey                  157
# 2    AVENUE LEON BLUM  01500      amberieu en bugey                  633
#
#    nb_adresses_final id_brut_miom
# 0              448.0   01001_0001
# 1              143.0   01002_0001
# 2              630.0   01004_0001

# %%
df_bv_finale_outer.rename(columns={"id_brut_reu": "id_brut_bv_reu"}, inplace=True)
df_bv_finale_outer.to_parquet("table_bv_finale.parquet", index=False)

# %%
os.system(f"mc cp table_bv_finale.parquet s3/projet-adresses-reu/table_bv_finale.parquet")

# %%
rebuts_finaux_reu = df_bv_originale[~df_bv_originale.id_brut_reu.isin(df_bv_finale_inner.id_brut_reu)].sort_values('id_brut_reu')

rebuts_finaux_miom = df_bv_miom[~df_bv_miom.id_brut_miom.isin(df_bv_finale_inner.id_brut_miom)].sort_values('id_brut_miom')
rebuts_finaux_miom = rebuts_finaux_miom[rebuts_finaux_miom['departement_miom'].apply(lambda x: x.isnumeric() and x[:2] != '98')]
# rebuts_finaux_miom = rebuts_finaux_miom[rebuts_finaux_miom["code_commune"].isin(set(rebuts_finaux_reu["code_commune"]))]

# %%
rebuts_finaux_reu.to_parquet("rebuts_reu.parquet", index=False)
rebuts_finaux_reu
# Out:
#        id_brut_reu id_brut_insee code_commune code  \
# 3098     06088_533          None        06088  533
# 3739   07230_1 - 1      7230_1 1        07230  1 1
# 4584        09123_          None        09123
# 5279     10387_101     10387_101        10387  101
# 5280     10387_102     10387_102        10387  102
# ...            ...           ...          ...  ...
# 62376    90010_L-2     90010_L 2        90010  l 2
# 62377    90010_L-3     90010_L 3        90010  l 3
# 62378    90010_M-1     90010_M 1        90010  m 1
# 62379    90010_N-1     90010_N 1        90010  n 1
# 62380    90010_N-2     90010_N 2        90010  n 2
#
#                                      libelle_reu num_voie_reu  \
# 3098                             philippe seguin            6
# 3739                                      mairie
# 4584                                      unique
# 5279                   hotel de ville 1er bureau
# 5280                  hotel de ville 2eme bureau
# ...                                          ...          ...
# 62376                ecole maternelle des barres            9
# 62377               ecole elementaire des barres           10
# 62378  ecole maternelle antoine de saint exupery
# 62379                            gymnase serzian
# 62380              maison de quartier des forges            3
#
#                      voie_reu cp_reu                commune_reu  \
# 3098         RUE ALFRED BINET  06000                       nice
# 3739               LE VILLAGE  07200  saint etienne de boulogne
# 4584                   Mairie  09350                     fornex
# 5279   place Alexandre Israël  10000                     troyes
# 5280   place Alexandre Israël  10000                     troyes
# ...                       ...    ...                        ...
# 62376          Via d'Auxelles  90000                    belfort
# 62377     rue Jules Siegfried  90000                    belfort
# 62378          Rue de la Paix  90000                    belfort
# 62379             Rue Floréal  90000                    belfort
# 62380        rue de Marseille  90000                    belfort
#
#        nb_adresses_initial  nb_adresses_final
# 3098                    65               65.0
# 3739                    96               70.0
# 4584                     1                1.0
# 5279                   296              295.0
# 5280                   306              301.0
# ...                    ...                ...
# 62376                  276              274.0
# 62377                  278              278.0
# 62378                  183              183.0
# 62379                  260              259.0
# 62380                  422              419.0
#
# [124 rows x 11 columns]

# %%
rebuts_finaux_miom.to_parquet("rebuts_miom.parquet", index=False)
rebuts_finaux_miom
# Out:
#       id_brut_miom id_clean_miom code_commune code     commune_miom  \
# 104     01053_0020      01053_20        01053   20  Bourg-en-Bresse
# 1054    02408_0020      02408_20        02408   20             Laon
# 1838    03190_0020      03190_20        03190   20          Moulins
# 2083    04070_0013      04070_13        04070   13  Digne-les-Bains
# 2150    04126_0001       04126_1        04126    1         Montclar
# ...            ...           ...          ...  ...              ...
# 66996   ZA105_0013      97105_13        97105   13      Basse-Terre
# 67411   ZB209_0061      97209_61        97209   61   Fort-de-France
# 67681   ZC302_0033      97302_33        97302   33          Cayenne
# 68123   ZD411_0134     97411_134        97411  134      Saint-Denis
# 68831   ZM611_0183     97611_183        97611  183        Mamoudzou
#
#       departement_miom libelle_departement_miom
# 104                 01                      Ain
# 1054                02                    Aisne
# 1838                03                   Allier
# 2083                04  Alpes-de-Haute-Provence
# 2150                04  Alpes-de-Haute-Provence
# ...                ...                      ...
# 66996              971               Guadeloupe
# 67411              972               Martinique
# 67681              973                   Guyane
# 68123              974               La Réunion
# 68831              976                  Mayotte
#
# [242 rows x 7 columns]
